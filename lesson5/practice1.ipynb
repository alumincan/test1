# %%
print("hello world")
# Out:
# hello world

# %%
a = 13
if a >= 14:
    a-=2
    print(a)
else:
    a+=2
    print(a)
# Out:
# 15

# %%
age = 21
if age >= 18:
    print("我已經可以投票")
print("應用程式結束")
# Out:
# 我已經可以投票
# 應用程式結束

# %%
furry = True
small = True

if furry:
    print("這是上有毛的")
    if small:
        print("這是小的")
        print("它是貓")
    else:
        print("這是大的")
        print("它是熊")
else:
    print("這是代表沒有毛")
    if small:
        print("這是小的")
        print("它是小螞蟻")
    else:
        print("這是大的")
        print("它是人類或是沒毛的猴")
# Out:
# 這是上有毛的
# 這是小的
# 它是貓

# %%
# 如果 x 不是負數，則傳回值為 x ** (1 / y)
# 如果 x 是負數而且 y 為偶數，則傳回值為 "虛數"
# 如果 x 是負數而且 y 為奇數，則傳回值為 -(-x) ** (1 / y)

x = int(input("請輸入 x:"))
y = int(input("請輸入 y:"))

if x >= 0:
    root = x ** (1/y)
else:
    if y % 2 == 0:
        root = "虛數"
    else:
        root = -(-x) ** (1 / y)

print("root=", root)
# Out:
# 請輸入 x: -2
# 請輸入 y: 2
# root= 虛數

# %%
# 百貨公司週年慶:會員打 9 折
# 折扣後最低不得低於 100 元

money = int(input("請輸入消費金額:"))
is_member = input("是否為會員?(y,n)")

# 請完成:如果是會員(is_member 等於 "y"),才進入打折流程
if (   is_member == 'y' ):
    # 請完成:把 money 打 9 折(乘以 0.9)
    money = money * 0.9
    
    # 請完成:如果打折後金額小於 100,就把 money 設成 100
    if  money < 100  :
        money = 100

# 請完成:用 round() 把金額四捨五入後印出
print(  round(money)           )
# Out:
# 請輸入消費金額: 202
# 是否為會員?(y,n) n
# 202

# %%
# 接收輸入並轉換為整數
score = int(input("請輸入分數: "))

# 使用 if-elif-else 進行多條件判斷（由大到小）
if score >= 90:
    grade = '優'
elif score >= 80:
    grade = '甲'
elif score >= 70:
    grade = '乙'
elif score >= 60:
    grade = '丙'
else:
    grade = '丁'

# 輸出結果
print(f"您的成績評等為: {grade}")
# Out:
# 請輸入分數:  -1
# 您的成績評等為: 丁
