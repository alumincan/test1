# %%
print("hello world")
# Out:
# hello world

# %%
a = 13
if a >= 14:
    a-=2
    print(a)
else:
    a+=2
    print(a)
# Out:
# 15

# %%
age = 21
if age >= 18:
    print("我已經可以投票")
print("應用程式結束")
# Out:
# 我已經可以投票
# 應用程式結束

# %%
furry = True
small = True

if furry:
    print("這是上有毛的")
    if small:
        print("這是小的")
        print("它是貓")
    else:
        print("這是大的")
        print("它是熊")
else:
    print("這是代表沒有毛")
    if small:
        print("這是小的")
        print("它是小螞蟻")
    else:
        print("這是大的")
        print("它是人類或是沒毛的猴")
# Out:
# 這是上有毛的
# 這是小的
# 它是貓
