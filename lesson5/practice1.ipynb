# %%
print("hello world")
# Out:
# hello world

# %%
a = 13
if a >= 14:
    a-=2
    print(a)
else:
    a+=2
    print(a)
# Out:
# 15

# %%
age = 21
if age >= 18:
    print("我已經可以投票")
print("應用程式結束")
# Out:
# 我已經可以投票
# 應用程式結束
