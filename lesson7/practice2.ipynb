# %%
#list的typehint
#list
rabbits:list[str] = ["Flopsy", "Mopsy", "Cottontail", "Peter"]

for s in rabbits:
    print(s)
# Out:
# Flopsy
# Mopsy
# Cottontail
# Peter

# %%
country_code:dict[str,str] = {"tw":"Taiwan", "jp": "Japan", "hk":"Hong Kong", "kr": "Korea"}

for code in country_code:
    print(f"key = {code}")
    print(f"value = {country_code[code]}")
    print("======  我是分隔線  =====")
# Out:
# key = tw
# value = Taiwan
# ======  我是分隔線  =====
# key = jp
# value = Japan
# ======  我是分隔線  =====
# key = hk
# value = Hong Kong
# ======  我是分隔線  =====
# key = kr
# value = Korea
# ======  我是分隔線  =====

# %%
while True:
    stuff = input("請輸入小寫英文字[按q會離開]:")
    if stuff == 'q':
        break
    print(stuff.capitalize())
print("程式結束")
# Out:
# 請輸入小寫英文字[按q會離開]: g
# G
# 請輸入小寫英文字[按q會離開]: q
# 程式結束

# %%
#累加正偶數
#設計一個程式讓使用者輸入數值，只有正偶數值會被加總，若輸入奇數則跳過，輸入負數則結束程式：
total:int = 0
num:int = 0
while True:
    input_value = int(input(f"請輸入第{num + 1}個數值:"))    
    if input_value < 0 and input_value == _empty:
        break
        
    num += 1

    if input_value % 2 == 1:
        continue

    total += input_value

print(f"輸入的次數是{num}, ，所有輸入的正偶數的加總是:{total}")
# Out:
# 請輸入第1個數值:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 6
#       2 #設計一個程式讓使用者輸入數值，只有正偶數值會被加總，若輸入奇數則跳過，輸入負數則結束程式：
#       3 total:int = 0
#       4 num:int = 0
#       5 while True:
# ----> 6     input_value = int(input(f"請輸入第{num + 1}個數值:"))
#       7     if input_value < 0 and input_value == _empty:
#       8         break
#       9
#
# ValueError: invalid literal for int() with base 10: ''
